# %% [markdown]
# ## Batch Gradient Descent

# %%
import numpy as np
np.random.seed(42)

# %%
eta=0.1 #learning rate
n_epochs=1000

# %%
m=len(X_b)

# %%
np.random.seed(42)
theta=np.random.randn(2,1)

# %%
for epoch in range(n_epochs):
    gradinets=(2/m)*X_b.T@(X_b @ theta - y.reshape(-1,1))
    theta=theta-eta*gradinets

# %% [markdown]
# ##

# %%
theta
# Out:
# array([[3.13232506e+00, 4.82224218e+00, 4.20515790e+00, 3.59721856e+00,
#         2.44608873e+00, 2.50369482e+00, 2.32204024e+00, 4.54670142e+00,
#         3.72249567e+00, 4.07404203e+00, 2.15329369e+00, 4.94260467e+00,
#         4.44435190e+00, 2.68834408e+00, 2.55518266e+00, 2.64707803e+00,
#         2.84252142e+00, 3.54150308e+00, 3.25662424e+00, 2.72733593e+00,
#         3.86517071e+00, 2.44458711e+00, 2.87694529e+00, 3.07562682e+00,
#         3.22667288e+00, 4.31346335e+00, 2.56474989e+00, 3.46247559e+00,
#         3.76111514e+00, 2.17975632e+00, 4.01125315e+00, 2.52903015e+00,
#         2.22090982e+00, 4.83921202e+00, 4.70501898e+00, 4.42254066e+00,
#         2.91986433e+00, 2.53934055e+00, 4.03346298e+00, 3.35061222e+00,
#         2.36264353e+00, 3.36866293e+00, 2.21744784e+00, 4.80315451e+00,
#         2.85544314e+00, 3.89662811e+00, 3.07541266e+00, 3.42001896e+00,
#         3.69881655e+00, 2.77360893e+00, 4.80970025e+00, 4.26876870e+00,
# ...
